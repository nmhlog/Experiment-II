                          'f1_score_test' : 0.8956132911880349,
                          'accuracy_score_test' : 0.8956132911880349,
                          'cohen_kappa_score_test' : 0.7899779293512029}
agg_time_train_tf_inception_resnet_v2=[55.652838945388794, 54.91658639907837, 54.45914149284363, 54.97219777107239, 54.465731620788574, 54.49021530151367, 54.60710787773132, 54.68688774108887, 54.93366527557373, 54.88211393356323, 54.50675392150879, 54.92403745651245, 54.637014627456665, 54.660367488861084, 54.73271918296814, 54.36144828796387, 54.216700315475464, 54.188170433044434, 54.23382067680359, 54.36100888252258, 54.23617959022522, 54.159661531448364, 54.3374707698822, 54.21612191200256, 54.63663458824158, 54.52429962158203, 54.62193417549133, 54.757187843322754, 54.780353307724, 55.05214238166809, 55.117188453674316]
agg_time_val_tf_inception_resnet_v2 =[9.128705024719238, 8.972826719284058, 8.968074798583984, 8.904584884643555, 8.96219801902771, 8.960533380508423, 8.969839572906494, 8.96360182762146, 8.89178729057312, 8.893378496170044, 8.96429705619812, 8.900060653686523, 8.966907739639282, 8.935570001602173, 8.86061429977417, 8.917716979980469, 8.930628061294556, 8.91185212135315, 8.920514822006226, 8.904004096984863, 8.940876245498657, 8.909573793411255, 8.918028593063354, 8.91440224647522, 8.860118627548218, 8.990377187728882, 9.00888442993164, 9.009844064712524, 9.005221128463745, 9.009212970733643, 8.904575824737549]

# %%
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{:.2f}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')
import matplotlib
matplotlib.rcParams.update({'font.size': 22})

# %%
time_seresnet50 = [sum(agg_time_train_seresnet50_colab)/sum(agg_time_train_seresnet50),sum(agg_time_val_seresnet50_colab)/sum(agg_time_val_seresnet50),sum(agg_time_train_seresnet50_colab+agg_time_val_seresnet50_colab)/sum(agg_time_train_seresnet50+agg_time_val_seresnet50)]

time_inception_resnet_v2 = [sum(agg_time_train_inception_resnet_v2_colab)/sum(agg_time_train_inception_resnet_v2),sum(agg_time_val_inception_resnet_v2_colab)/sum(agg_time_val_inception_resnet_v2),sum(agg_time_train_inception_resnet_v2_colab+agg_time_val_inception_resnet_v2_colab)/sum(agg_time_train_inception_resnet_v2+agg_time_val_inception_resnet_v2)]
x = np.arange(len(time_inception_resnet_v2))  # the label locations
width = 0.4
fig, ax = plt.subplots(figsize=(15,10))
rects1 = ax.bar(x + width, time_seresnet50, width, label='resnet50')
rects2 = ax.bar(x + width*2, time_inception_resnet_v2, width, label='transfer learning inception_resnet_v2')
plt.xticks(x+width*1.5,['Training time speed up','Validation time speed up','Total time speed up'],rotation=40)
plt.legend( (rects1, rects2), ('resnet50', 'inception resnet v2') ,loc='lower right')
autolabel(rects1)
autolabel(rects2)

# %%
fig, ax = plt.subplots(figsize=(40,15))
ax.plot(agg_time_train_seresnet50_colab,'o-',label='seresnet50_colab')
ax.plot(agg_time_train_seresnet50,'o-',label='seresnet50')
ax.plot(agg_time_train_inception_resnet_v2_colab,'o-',label='inception_resnet_v2_colab')
ax.plot(agg_time_train_inception_resnet_v2,'o-',label='inception_resnet_v2')
ax.set_xticks(list(range(0,50,5)))
# ax.set_xticklabels(list(range(0,50,5)),fontsize=20)
# ax.set_yticklabels(fontsize=20)

# ax.set_xticks(np.arange(0,50,1),minor=True)
# ax.set_yticks(np.arange(0,int(max(agg_time_train_inception_resnet_v2_colab)+5),5))
# ax.set_yticks(np.arange(0,int(max(agg_time_train_inception_resnet_v2_colab))+5,1), minor=True)
# ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)
ax.set_xlim(0,49,0)
ax.set_ylabel('time (s)',fontsize=20)
ax.set_xlabel('epoch ',fontsize=20)
plt.title("Training Time")
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5),fontsize=20)
plt.savefig('Training Time.jpeg',transparent=True,bbox_inches ="tight",)

plt.show()

# %%
from matplotlib.ticker import MultipleLocator

# %%
fig, ax = plt.subplots(figsize=(40,15))
ax.plot(agg_time_val_seresnet50_colab,'o-',label='seresnet50_colab')
ax.plot(agg_time_val_seresnet50,'o-',label='seresnet50')
ax.plot(agg_time_val_inception_resnet_v2_colab,'o-',label='inception_resnet_v2_colab')
ax.plot(agg_time_val_inception_resnet_v2,'o-',label='inception_resnet_v2')
ax.set_xticks(list(range(0,50,5)))
ax.set_xticks(np.arange(0,50,1),minor=True)
ax.set_yticks(np.arange(0,int(max(agg_time_val_inception_resnet_v2_colab)+5),5))
ax.set_yticks(np.arange(0,int(max(agg_time_val_inception_resnet_v2_colab))+5,1), minor=True)
ax.set_ylabel('time (s)',fontsize=20)
ax.set_xlabel('epoch ',fontsize=20)
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)
ax.set_xlim(0,49,0)
plt.title("Validation Time",fontsize=20)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5),fontsize=20)
plt.savefig('validation time.jpeg',transparent=True,bbox_inches ="tight",)

plt.show()

# %%
labels = list(seresnet50_eval.keys())
x = np.arange(len(labels))  # the label locations
width = 0.4
fig, ax = plt.subplots(figsize=(20,15))
rects1 = ax.bar(x + width, list(seresnet50_eval.values()), width, label='seresnet50')
rects2 = ax.bar(x + width, list(tf_seresnet50.values()), width, label='transfer learning resnet50')
rects3 = ax.bar(x + width*2, list(inception_resnet_v_eval.values()), width, label='inception_resnet_v2')
rects4 = ax.bar(x + width*2, list(tf_inception_resnet_v2.values()), width, label='transfer learning inception_resnet_v2')
plt.xticks(x+width*1.5,labels)
plt.yticks(np.arange(0.1,1.1,0.1))
plt.legend( (rects1, rects2, rects3,rects4), ('resnet50', 'transfer learning resnet50', 'inception_resnet_v2','transfer learning inception_resnet_v2') ,loc='lower right')
autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
plt.show()

# %%
labels = list(seresnet50_eval.keys())
x = np.arange(len(labels))  # the label locations
width = 0.20
fig, ax = plt.subplots(figsize=(20,15))
rects1 = ax.bar(x + width, list(seresnet50_eval_colab.values()), width, label='resnet50_eval_colab')
rects2 = ax.bar(x + width*3, list(seresnet50_eval.values()), width, label='resnet50_eval')
rects3 = ax.bar(x + width*2, list(inception_resnet_v2_eval_colab.values()), width, label='inception_resnet_v2_eval_colab')
rects4 = ax.bar(x + width*4, list(inception_resnet_v_eval.values()), width, label='inception_resnet_v2_eval')
plt.xticks(x+width*2,labels)
plt.legend( (rects1, rects2, rects3,rects4), ('resnet50_eval_colab', 'resnet50_eval', 'inception_resnet_v2_eval_colab','inception_resnet_v2_eval'),loc='lower right')
autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
plt.show()
